# %% [markdown]
# ### **Imports**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from statsmodels.tsa.stattools import adfuller  
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import acf, plot_acf, pacf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.api import VAR
import statsmodels.api as sm

import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)

# %%
train = pd.read_csv('datasets/clean-avg-train-combined-with-location-data.csv')
train.head()
# Out:
#    station_id station_name month_beginning  avg_weekday_rides  \
# 0       40900       Howard      2001-01-01             6233.9
# 1       41190       Jarvis      2001-01-01             1489.1
# 2       40100        Morse      2001-01-01             4412.5
# 3       41300       Loyola      2001-01-01             4664.5
# 4       40760    Granville      2001-01-01             3109.8
#
#    avg_saturday_rides  avg_sunday-holiday_rides  month_total        lat  \
# 0              3814.5                    2408.6       164447  42.019063
# 1              1054.0                     718.0        40567  42.015876
# 2              3064.5                    2087.8       119772  42.008362
# 3              3156.0                    1952.8       125008  42.001073
# 4              2126.0                    1453.8        84189  41.993664
#
#         long
# 0 -87.672892
# 1 -87.669092
# 2 -87.665909
# 3 -87.661061
# 4 -87.659202

# %%
train.columns
# Out:
# Index(['station_id', 'station_name', 'month_beginning', 'avg_weekday_rides',
#        'avg_saturday_rides', 'avg_sunday-holiday_rides', 'month_total', 'lat',
#        'long'],
#       dtype='object')

# %%
df=train[['month_beginning', 'month_total', 'avg_weekday_rides', 'avg_saturday_rides', 'avg_sunday-holiday_rides']].set_index('month_beginning')
df.head()
# Out:
#                  month_total  avg_weekday_rides  avg_saturday_rides  \
# month_beginning
# 2001-01-01            164447             6233.9              3814.5
# 2001-01-01             40567             1489.1              1054.0
# 2001-01-01            119772             4412.5              3064.5
# 2001-01-01            125008             4664.5              3156.0
# 2001-01-01             84189             3109.8              2126.0
#
#                  avg_sunday-holiday_rides
# month_beginning
# 2001-01-01                         2408.6
# 2001-01-01                          718.0
# 2001-01-01                         2087.8
# 2001-01-01                         1952.8
# 2001-01-01                         1453.8

# %%
df.index=pd.DatetimeIndex(df.index)
df.head()
# Out:
#                  month_total  avg_weekday_rides  avg_saturday_rides  \
# month_beginning
# 2001-01-01            164447             6233.9              3814.5
# 2001-01-01             40567             1489.1              1054.0
# 2001-01-01            119772             4412.5              3064.5
# 2001-01-01            125008             4664.5              3156.0
# 2001-01-01             84189             3109.8              2126.0
#
#                  avg_sunday-holiday_rides
# month_beginning
# 2001-01-01                         2408.6
# 2001-01-01                          718.0
# 2001-01-01                         2087.8
# 2001-01-01                         1952.8
# 2001-01-01                         1453.8

# %%
df.to_csv('time_series_df.csv')

# %%
# Code modified from code written by Matthew Garton
def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    plt.figure(figsize=(18,9))

    for col in cols:

        plt.plot(df[col])
        
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18);

# %%
# Code modified from code written by Matthew Garton
def plot_multi(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    fig, ax = plt.subplots(figsize = (14, 6))

    plt.figure(figsize=(18,9))

    for col in cols:

        plt.plot(df[col])
        
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18);

# %%
# Generate a time plot of our data.
plot_series(df, ['month_total'], 
            title = 'Total Monthly Train Ridership', steps=10000)

# %%
# Generate a time plot of our data.
plot_series(df, ['avg_weekday_rides'], 
            title = 'Avg Weekday Monthly Train Ridership', steps=10000)

# %%
# Generate a time plot of our data.
plot_series(df, ['avg_saturday_rides'], 
            title = 'Avg Saturday Monthly Train Ridership', steps=10000)

# %%
# Generate a time plot of our data.
plot_series(df, ['avg_sunday-holiday_rides'], 
            title = 'Avg Sunday & Holiday Monthly Train Ridership', steps=10000)

# %%
plot_series(df.resample('YS',
                        closed = 'left').mean(),
            ['month_total'],
            title='Total Monthly Ridership',
            steps = 2)

# %%
plot_series(df.resample('MS',
                        closed = 'left').mean(),
            ['month_total'],
            title = "Train Monthly Ridership Totals",
            steps = 24)

# %%
df=df[df.index < '2020-03-01']

# %%
plot_series(df.resample('MS',
                        closed = 'left').mean(),
            ['month_total'],
            title = "Train Monthly Ridership Totals",
            steps = 60)

# %%
df = df.resample('MS', closed = 'left').mean()

# %%
df.head()
# Out:
#                   month_total  avg_weekday_rides  avg_saturday_rides  \
# month_beginning
# 2001-01-01       86628.776978        3430.124460         1568.921583
# 2001-02-01       80480.561151        3500.872662         1560.342446
# 2001-03-01       90980.474820        3540.015827         1743.936691
# 2001-04-01       86597.215827        3526.564029         1723.307194
# 2001-05-01       92643.000000        3613.837410         1753.089928
#
#                  avg_sunday-holiday_rides
# month_beginning
# 2001-01-01                     978.086331
# 2001-02-01                    1055.597122
# 2001-03-01                    1095.145324
# 2001-04-01                    1129.257554
# 2001-05-01                    1225.258993

# %%
plot_series(df, ['month_total'], title = "Average Monthly Total Ridership", steps = 50)

# %%
df.to_csv('time_series_df_resampled.csv')

# %%
# Code written by Joseph Nelson 
# Improved by Hovanes Gasparian
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:3], index=['Test Statistic','p-value', 'Lag Used'])
    return dfoutput

# %%
df['first_diff_total']=df['month_total'].diff(1)

# %%
df['second_diff_total']=df['month_total'].diff(1).diff(1)

# %%
print(f"Stationarity of month total:\n{interpret_dftest(adfuller(df['month_total']))}")
print()
print(f"Stationarity of first-differenced month total:\n{interpret_dftest(adfuller(df['first_diff_total'].dropna()))}")
print()
print(f"Stationarity of second-differenced month total:\n{interpret_dftest(adfuller(df['second_diff_total'].dropna()))}")
# Out:
# Stationarity of month total:
# Test Statistic    -1.484788
# p-value            0.541023
# Lag Used          14.000000
# dtype: float64
#
# Stationarity of first-differenced month total:
# Test Statistic    -3.342890
# p-value            0.013067
# Lag Used          13.000000
# dtype: float64
#
# Stationarity of second-differenced month total:
# Test Statistic   -1.609010e+01
# p-value           5.264628e-29
# Lag Used          1.200000e+01
# dtype: float64

# %%
plot_series(df, ['first_diff_total'], title = "First-Order Differenced Data", steps = 50)

# %%
plot_series(df, ['second_diff_total'], title = "First-Order Differenced Data", steps = 50)

# %%
y_train, y_test = train_test_split(df['month_total'],
                                   test_size = 0.2,
                                   shuffle = False)

# %%
# Starting AIC, p, and q.
best_aic = 99 * (10 ** 16)
best_p = 0
best_q = 0

# Use nested for loop to iterate over values of p and q.
for p in range(15):
    for q in range(15):
        
        # Insert try and except statements.
        try:
            
            # Fitting an ARIMA(p, 1, q) model.
            print(f'Attempting to fit ARIMA({p},1,{q})')
            
            # Instantiate ARIMA model.
            arima = ARIMA(endog = y_train.astype(float).dropna(), # endog = Y variable
                          order = (p,1,q)) # values of p, d, q
            
            # Fit ARIMA model.
            model = arima.fit()

            # Print out AIC for ARIMA(p, 1, q) model.
            print(f'The AIC for ARIMA({p},1,{q}) is: {model.aic}')

            # Is my current model's AIC better than our best_aic?
            if model.aic < best_aic:
                
                # If so, let's overwrite best_aic, best_p, and best_q.
                best_aic = model.aic
                best_p = p
                best_q = q

        except:
            pass
print()
print()
print('MODEL FINISHED!')
print(f'Our model that minimizes AIC on the training data is the ARIMA({best_p},1,{best_q}).')
print(f'This model has an AIC of {best_aic}.')
# Out:
# Attempting to fit ARIMA(0,1,0)
# The AIC for ARIMA(0,1,0) is: 3754.905311932136
# Attempting to fit ARIMA(0,1,1)
# The AIC for ARIMA(0,1,1) is: 3750.530288181762
# Attempting to fit ARIMA(0,1,2)
# The AIC for ARIMA(0,1,2) is: 3728.3844750188314
# Attempting to fit ARIMA(0,1,3)
# C:\Users\Brianna\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# ...

# %%
model_arima = ARIMA(endog=y_train.astype(float).dropna(),
                         order = (10,1,8))

arima_fit = model_arima.fit()

short_period = 5
long_period = 30

forecast_short = arima_fit.forecast(steps=short_period)
forecast_long = arima_fit.forecast(steps=long_period)
# Out:
# C:\Users\Brianna\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
sns.set_theme()
# Plot data.
plt.figure(figsize=(20,10))

# Plot training data.
plt.plot(y_train.index, pd.DataFrame(y_train), color = 'blue')

# Plot testing data.
plt.plot(y_test.index, pd.DataFrame(y_test), color = 'orange')

# Plot predicted test values.
# plt.plot(y_test.index, preds, color = 'green')
plt.plot(y_test.index[0:short_period],forecast_short[0], color = 'green')

plt.title(label = 'Train Short Term Forecast with ARIMA(10, 1, 8) Predictions', fontsize=20)
plt.savefig('data_viz/train_shorterm_forecast.png');

# %%
# Plot data.
plt.figure(figsize=(20,10))

# Plot training data.
plt.plot(y_train.index, pd.DataFrame(y_train), color = 'blue')

# Plot testing data.
plt.plot(y_test.index, pd.DataFrame(y_test), color = 'orange')

# Plot predicted test values.
#plt.plot(y_test.index, preds, color = 'green')
plt.plot(y_test.index[0:long_period],forecast_long[0], color = 'green')

plt.title(label = 'Train Long Term Forecast with ARIMA(10,1,8) Predictions', fontsize=20);
plt.savefig('data_viz/train_longterm_forecast.png')

# %%
y_train
# Out:
# month_beginning
# 2001-01-01     86628.776978
# 2001-02-01     80480.561151
# 2001-03-01     90980.474820
# 2001-04-01     86597.215827
# 2001-05-01     92643.000000
#                   ...
# 2015-12-01    106741.804196
# 2016-01-01    104108.993007
# 2016-02-01    106817.069930
# 2016-03-01    117008.048951
# 2016-04-01    113344.412587
# Freq: MS, Name: month_total, Length: 184, dtype: float64

# %%
y_test
# Out:
# month_beginning
# 2016-05-01    116492.041958
# 2016-06-01    120088.678322
# 2016-07-01    118116.020979
# 2016-08-01    118528.538462
# 2016-09-01    120101.384615
# 2016-10-01    125705.097902
# 2016-11-01    114576.447552
# 2016-12-01     98227.188811
# 2017-01-01    102628.622378
# 2017-02-01     99330.377622
# 2017-03-01    112808.020979
# 2017-04-01    106511.468531
# 2017-05-01    114312.671329
# 2017-06-01    117510.454545
# 2017-07-01    111724.860140
# 2017-08-01    118549.048611
# 2017-09-01    117434.013889
# 2017-10-01    121921.937931
# 2017-11-01    108563.854167
# 2017-12-01     95484.159722
# 2018-01-01    100314.902778
# 2018-02-01     96006.687500
# 2018-03-01    109762.979167
# 2018-04-01    106731.548611
# 2018-05-01    113683.645833
# 2018-06-01    112503.861111
# 2018-07-01    112850.673611
# 2018-08-01    118110.618056
# 2018-09-01    114861.000000
# 2018-10-01    125532.125000
# 2018-11-01    106218.520833
# 2018-12-01     93845.243056
# ...
